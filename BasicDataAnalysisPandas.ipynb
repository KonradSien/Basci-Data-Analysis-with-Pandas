# %% [markdown]
# # Basic Data Analisys using Pandas and Numpy

# %% [markdown]
# #### Weather Data Set

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("file.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ### 1. Find the unique "Wind Speed" values in the data set

# %%
unique_wind_speed=df["Wind Speed_km/h"].unique()
print(unique_wind_speed)
# Out:
# [ 4  7  6  9 15 13 20 22 19 24 30 35 39 32 33 26 44 43 48 37 28 17 11  0
#  83 70 57 46 41 52 50 63 54  2]

# %% [markdown]
# ### 2. Find the numbers of times when the "Weather" is excatly "Clear:"

# %%
df[df["Weather"]=="Clear"].shape[0]
# Out:
# 1326

# %% [markdown]
# ### 3. Find the numbers of times when the "Wind Speed_km/h" was excatly "4km/h:"

# %%
df[df["Wind Speed_km/h"]==4].shape[0]
# Out:
# 474

# %%
df=df.rename(columns={"Wind Speed_km/h":"wind_speed"})

# %%
df.query("wind_speed==4").shape[0]
# Out:
# 474

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed  \
# 0  1/1/2012 0:00    -1.8              -3.9         86           4
# 1  1/1/2012 1:00    -1.8              -3.7         87           4
# 2  1/1/2012 2:00    -1.8              -3.4         89           7
# 3  1/1/2012 3:00    -1.5              -3.2         88           6
# 4  1/1/2012 4:00    -1.5              -3.3         88           7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# ### 4. What is the mean Visibility

# %%
df.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ### 5. What is the Standard Deviation of Pressure

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ### 6. What is the Variance of Relatice Humidity"

# %%
df["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ### 7. Find all instances when Snow was recorded

# %%
df[df.Weather.str.contains("Snow")].shape[0]
# Out:
# 583

# %%
#filtering
#df[df.Weather=="Snow"] 

df[df.Weather.str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed  \
# 41      1/2/2012 17:00    -2.1              -9.5         57          22
# 44      1/2/2012 20:00    -5.6             -13.4         54          24
# 45      1/2/2012 21:00    -5.8             -12.8         58          26
# 47      1/2/2012 23:00    -7.4             -14.1         59          17
# 48       1/3/2012 0:00    -9.0             -16.0         57          28
# ...                ...     ...               ...        ...         ...
# 8779  12/31/2012 19:00     0.1              -2.7         81          30
# 8780  12/31/2012 20:00     0.2              -2.4         83          24
# 8781  12/31/2012 21:00    -0.5              -1.5         93          28
# 8782  12/31/2012 22:00    -0.2              -1.8         89          28
# 8783  12/31/2012 23:00     0.0              -2.1         86          30
#
#       Visibility_km  Press_kPa       Weather
# 41             25.0      99.66  Snow Showers
# ...

# %% [markdown]
# ### 8. Find all instances when Wind Speed is above 24 and visibility is 25

# %%
df.query("wind_speed> 24 and Visibility_km==25 ")

#also worked
#df[(df.wind_speed> 24) & (df.Visibility_km==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed  \
# 23      1/1/2012 23:00     5.3               2.0         79          30
# 24       1/2/2012 0:00     5.2               1.5         77          35
# 25       1/2/2012 1:00     4.6               0.0         72          39
# 26       1/2/2012 2:00     3.9              -0.9         71          32
# 27       1/2/2012 3:00     3.7              -1.5         69          33
# ...                ...     ...               ...        ...         ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76          26
# 8753  12/30/2012 17:00   -12.1             -15.8         74          28
# 8755  12/30/2012 19:00   -13.4             -16.5         77          26
# 8759  12/30/2012 23:00   -12.1             -15.1         78          28
# 8760   12/31/2012 0:00   -11.1             -14.4         77          26
#
#       Visibility_km  Press_kPa        Weather
# 23             25.0      99.31         Cloudy
# ...

# %% [markdown]
# ### 9. What is the mean value of each column against each weather condition?

# %%
df.groupby("Weather").mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ### 10. What is the minimum and maximum value of each column against each weather condition?

# %%
#max
df.groupby("Weather").max()

#min
df.groupby("Weather").min()
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# Freezing Drizzle,Haze                      -5.0              -7.7         83
# ...

# %% [markdown]
# ### 11. Show all the records where weather is fog

# %%
df[df.Weather=="Fog"]
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed  Visibility_km  \
# 0       -1.8              -3.9         86           4            8.0
# 1       -1.8              -3.7         87           4            8.0
# 4       -1.5              -3.3         88           7            4.8
# 5       -1.4              -3.3         87           9            6.4
# 6       -1.5              -3.1         89           7            6.4
# ...      ...               ...        ...         ...            ...
# 8716   -16.0             -17.2         90           6            9.7
# 8717   -14.8             -15.9         91           4            6.4
# 8718   -13.8             -15.3         88           4            9.7
# 8719   -14.8             -16.4         88           7            8.0
# 8722   -12.0             -13.3         90           7            6.4
#
#       Press_kPa Weather
# 0        101.24     Fog
# 1        101.24     Fog
# 4        101.23     Fog
# 5        101.27     Fog
# ...

# %% [markdown]
# ### 12. Find all instances when weather is clear or visibility is above 40

# %%
df.query("Weather=='Clear' or Visibility_km>40")
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed  Visibility_km  \
# 67     -16.9             -24.8         50          24           25.0
# 106     -6.0             -10.0         73          17           48.3
# 107     -5.6             -10.2         70          22           48.3
# 108     -4.7              -9.6         69          20           48.3
# 109     -4.4              -9.7         66          26           48.3
# ...      ...               ...        ...         ...            ...
# 8749   -12.4             -16.2         73          37           48.3
# 8750   -11.8             -16.1         70          37           48.3
# 8751   -11.3             -15.6         70          32           48.3
# 8752   -11.4             -15.5         72          26           48.3
# 8756   -13.8             -16.5         80          24           25.0
#
#       Press_kPa        Weather
# 67       101.74          Clear
# 106      100.45   Mainly Clear
# 107      100.41   Mainly Clear
# ...

# %% [markdown]
# ### 13. Find all instances when weather is clear and relative humidity is greater than 50 OR visibility is above 40

# %%
#rename column to easier usage with query function
df=df.rename(columns={"Rel Hum_%":"relative_humidity"})

# %%
df.query("(Weather=='Clear' and relative_humidity>50) or Visibility_km>40")

#df[(df.Weather=="Clear") & (df.relative_humidity>50) | (df.Visibility_km>40)]
# Out:
#       Temp_C  Dew Point Temp_C  relative_humidity  wind_speed  Visibility_km  \
# 106     -6.0             -10.0                 73          17           48.3
# 107     -5.6             -10.2                 70          22           48.3
# 108     -4.7              -9.6                 69          20           48.3
# 109     -4.4              -9.7                 66          26           48.3
# 110     -5.1             -10.7                 65          22           48.3
# ...      ...               ...                ...         ...            ...
# 8749   -12.4             -16.2                 73          37           48.3
# 8750   -11.8             -16.1                 70          37           48.3
# 8751   -11.3             -15.6                 70          32           48.3
# 8752   -11.4             -15.5                 72          26           48.3
# 8756   -13.8             -16.5                 80          24           25.0
#
#       Press_kPa        Weather
# ...
